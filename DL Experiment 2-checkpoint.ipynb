# %% [markdown]
# ## Name: Omkar Datir
# ## Roll No.: 015
# ## Subject: LP-IV(DL)
# ## Experiment No.02

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, Flatten
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train) , (x_test, y_test) = mnist.load_data() # Data loading
x_train, x_test = x_train/255.0 , x_test/255.0 #Normalizing the data

# %%
sns.heatmap(x_train[9])
plt.show()

# %%
model = Sequential([
Flatten(input_shape=(28,28)),
Dense(128, activation="relu"),
Dropout(0.2),
Dense(10)
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[ 0.08626071, -0.8754221 ,  0.03590138, -0.88226503, -0.49035418,
#          0.17003568, -0.09268123, -0.01643232,  0.21160287,  0.45129836]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.11527878, 0.04406521, 0.10961718, 0.04376471, 0.06476326,
#         0.12535232, 0.09639087, 0.10402803, 0.13067268, 0.16606696]],
#       dtype=float32)

# %%
loss_fn =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer="adam", loss = loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2971 - accuracy: 0.9132
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1442 - accuracy: 0.9573
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1080 - accuracy: 0.9672
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0868 - accuracy: 0.9726
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0750 - accuracy: 0.9771

# %%
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.0757 - accuracy: 0.9776 - 431ms/epoch - 1ms/step
# [0.07568967342376709, 0.9775999784469604]

# %%
val = model.fit(x_train, y_train, epochs=6, validation_data=(x_test, y_test),batch_size=200)
# Out:
# Epoch 1/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0367 - accuracy: 0.9887 - val_loss: 0.0651 - val_accuracy: 0.9810
# Epoch 2/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0356 - accuracy: 0.9892 - val_loss: 0.0635 - val_accuracy: 0.9804
# Epoch 3/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0342 - accuracy: 0.9898 - val_loss: 0.0623 - val_accuracy: 0.9818
# Epoch 4/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0319 - accuracy: 0.9902 - val_loss: 0.0640 - val_accuracy: 0.9810
# Epoch 5/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0324 - accuracy: 0.9896 - val_loss: 0.0651 - val_accuracy: 0.9816
# Epoch 6/6
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.0659 - val_accuracy: 0.9812

# %%
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("epoch")
plt.plot(val.history["accuracy"])
plt.plot(val.history["val_accuracy"])
plt.legend(["train","val"])
plt.show()
